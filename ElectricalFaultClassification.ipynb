# %%
#Reading the data from a csv file to a pandas dataframe
import io
import pandas as pd
df = pd.read_csv('classData.csv')
df
# Out:
#       G  C  B  A          Ia          Ib          Ic        Va        Vb  \
# 0     1  0  0  1 -151.291812   -9.677452   85.800162  0.400750 -0.132935
# 1     1  0  0  1 -336.186183  -76.283262   18.328897  0.312732 -0.123633
# 2     1  0  0  1 -502.891583 -174.648023  -80.924663  0.265728 -0.114301
# 3     1  0  0  1 -593.941905 -217.703359 -124.891924  0.235511 -0.104940
# 4     1  0  0  1 -643.663617 -224.159427 -132.282815  0.209537 -0.095554
# ...  .. .. .. ..         ...         ...         ...       ...       ...
# 7856  0  0  0  0  -66.237921   38.457041   24.912239  0.094421 -0.552019
# 7857  0  0  0  0  -65.849493   37.465454   25.515675  0.103778 -0.555186
# 7858  0  0  0  0  -65.446698   36.472055   26.106554  0.113107 -0.558211
# 7859  0  0  0  0  -65.029633   35.477088   26.684731  0.122404 -0.561094
# 7860  0  0  0  0  -64.598401   34.480799   27.250065  0.131669 -0.563835
#
#             Vc
# 0    -0.267815
# 1    -0.189099
# 2    -0.151428
# 3    -0.130570
# ...

# %%
#Checking for null values
df.isnull().sum()
# Out:
# G     0
# C     0
# B     0
# A     0
# Ia    0
# Ib    0
# Ic    0
# Va    0
# Vb    0
# Vc    0
# dtype: int64

# %%
#Creating a single output/label column
df['combined_faults_label'] = df['G'].astype(str)  + df['C'].astype(str) +  df['B'].astype(str)+df['A'].astype(str)
df.head()
# Out:
#    G  C  B  A          Ia          Ib          Ic        Va        Vb  \
# 0  1  0  0  1 -151.291812   -9.677452   85.800162  0.400750 -0.132935
# 1  1  0  0  1 -336.186183  -76.283262   18.328897  0.312732 -0.123633
# 2  1  0  0  1 -502.891583 -174.648023  -80.924663  0.265728 -0.114301
# 3  1  0  0  1 -593.941905 -217.703359 -124.891924  0.235511 -0.104940
# 4  1  0  0  1 -643.663617 -224.159427 -132.282815  0.209537 -0.095554
#
#          Vc combined_faults_label
# 0 -0.267815                  1001
# 1 -0.189099                  1001
# 2 -0.151428                  1001
# 3 -0.130570                  1001
# 4 -0.113983                  1001

# %%
# getting the shape and sixe of the dataframe
# shows number of rows and number of columns
print(df.shape)
print(df.size)
# Out:
# (7861, 11)
# 86471

# %%
# get an overview of the dataframe
df.describe()
# Out:
#                  G            C            B            A           Ia  \
# count  7861.000000  7861.000000  7861.000000  7861.000000  7861.000000
# mean      0.432006     0.411271     0.555527     0.571429    13.721194
# std       0.495387     0.492095     0.496939     0.494903   464.741671
# min       0.000000     0.000000     0.000000     0.000000  -883.542316
# 25%       0.000000     0.000000     0.000000     0.000000  -119.802518
# 50%       0.000000     0.000000     1.000000     1.000000     2.042805
# 75%       1.000000     1.000000     1.000000     1.000000   227.246377
# max       1.000000     1.000000     1.000000     1.000000   885.738571
#
#                 Ib           Ic           Va           Vb           Vc
# count  7861.000000  7861.000000  7861.000000  7861.000000  7861.000000
# mean    -44.845268    34.392394    -0.007667     0.001152     0.006515
# std     439.269195   371.107412     0.289150     0.313437     0.307897
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7861 entries, 0 to 7860
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   G                      7861 non-null   int64
#  1   C                      7861 non-null   int64
#  2   B                      7861 non-null   int64
#  3   A                      7861 non-null   int64
#  4   Ia                     7861 non-null   float64
#  5   Ib                     7861 non-null   float64
#  6   Ic                     7861 non-null   float64
#  7   Va                     7861 non-null   float64
#  8   Vb                     7861 non-null   float64
#  9   Vc                     7861 non-null   float64
#  10  combined_faults_label  7861 non-null   object
# dtypes: float64(6), int64(4), object(1)
# memory usage: 675.7+ KB

# %%
 df[df['combined_faults_label'] == '0110']
# Out:
#       G  C  B  A         Ia          Ib          Ic        Va        Vb  \
# 2263  0  1  1  0  41.764455  -93.940215   55.022192  0.517510 -0.003685
# 2264  0  1  1  0  42.394348 -105.038998   65.494029  0.518491 -0.008071
# 2265  0  1  1  0  43.010571 -105.734383   65.569977  0.511217  0.003798
# 2266  0  1  1  0  43.612456 -100.121739   59.347319  0.499096  0.025105
# 2267  0  1  1  0  44.202230  -95.078643   53.707382  0.487527  0.045052
# ...  .. .. .. ..        ...         ...         ...       ...       ...
# 3262  0  1  1  0 -54.290034 -136.096517  192.625747 -0.503500 -0.040943
# 3263  0  1  1  0 -54.931249 -124.016643  181.187060 -0.502331 -0.041107
# 3264  0  1  1  0 -55.560456 -111.905120  169.704756 -0.501039 -0.041262
# 3265  0  1  1  0 -56.177499  -99.764935  158.181668 -0.499625 -0.041406
# 3266  0  1  1  0 -56.782225  -87.599085  146.620640 -0.498088 -0.041539
#
#             Vc combined_faults_label
# 2263 -0.513825                  0110
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
#Plot the line currents and kine voltages in the same graph

xlims = (3267, 4362)
# xlims_voltages = (0 , 10000)

fig, ax = plt.subplots(nrows = 2, ncols = 1, figsize = (15,10))

df[['Ia', 'Ib', 'Ic']].plot.line(ax = ax[0])
ax[0].set_xlabel('index')
ax[0].set_xlim(left = xlims[0], right = xlims[1])
ax[0].set_ylabel('Current (Amps)')
ax[0].set_title('Plot of the Line Currents')


df[['Va', 'Vb', 'Vc']].plot.line(ax = ax[1])
ax[1].set_xlabel('index')
ax[1].set_ylabel('Voltage (kilovolts)')
ax[1].set_xlim(left = xlims[0], right= xlims[1])
ax[1].set_title('Plot of the Line Voltages')
# Out:
# Text(0.5, 1.0, 'Plot of the Line Voltages')

# %%
#Plot the line currents and kine voltages in the same graph

xlims = (4363, 5495)
# xlims_voltages = (0 , 10000)

fig, ax = plt.subplots(nrows = 2, ncols = 1, figsize = (15,10))

df[['Ia', 'Ib', 'Ic']].plot.line(ax = ax[0])
ax[0].set_xlabel('index')
ax[0].set_xlim(left = xlims[0], right = xlims[1])
ax[0].set_ylabel('Current (Amps)')
ax[0].set_title('Plot of the Line Currents')


df[['Va', 'Vb', 'Vc']].plot.line(ax = ax[1])
ax[1].set_xlabel('index')
ax[1].set_ylabel('Voltage (kilovolts)')
ax[1].set_xlim(left = xlims[0], right= xlims[1])
ax[1].set_title('Plot of the Line Voltages')
# Out:
# Text(0.5, 1.0, 'Plot of the Line Voltages')

# %%
xlims = (2263	, 3266)
# xlims_voltages = (0 , 10000)

fig, ax = plt.subplots(nrows = 2, ncols = 1, figsize = (15,10))

df[['Ia', 'Ib', 'Ic']].plot.line(ax = ax[0])
ax[0].set_xlabel('index')
ax[0].set_xlim(left = xlims[0], right = xlims[1])
ax[0].set_ylabel('Current (Amps)')
ax[0].set_title('Plot of the Line Currents')


df[['Va', 'Vb', 'Vc']].plot.line(ax = ax[1])
ax[1].set_xlabel('index')
ax[1].set_ylabel('Voltage (kilovolts)')
ax[1].set_xlim(left = xlims[0], right= xlims[1])
ax[1].set_title('Plot of the Line Voltages')
# Out:
# Text(0.5, 1.0, 'Plot of the Line Voltages')

# %%
# Plot each line's current and voltage on the same plot

info = (('Line A', 'Ia', 'Va'),
        ('Line B', 'Ib', 'Vb'),
        ('Line C', 'Ic', 'Vc'))   # tuple of tuples

nrows, ncols = 3, 1
counter = 0 # keeps track of the index of the dictionary


fig, axes = plt.subplots(nrows = nrows, ncols = ncols, figsize = (12,15))
for row in range(nrows):

  ax = axes[row]

  color1 = 'tab:blue'
  ax.plot(np.array(df.index), df[info[counter][1]], color = color1, label = info[counter][1])
  ax.set_ylabel('Current, Amps', color = color1)
  ax.set_xlabel('index')
  ax.set_title(f'{info[counter][0]} Current and Voltage')
  ax.set_xlim(left = xlims[0], right = xlims[1])
  # ax.legend()

  color2 = 'tab:orange'
  ax_sec = ax.twinx()
  ax_sec.plot(np.array(df.index), df[info[counter][2]], color = color2, label = info[counter][2])
  ax_sec.set_ylabel('Voltage, kilovolts', color = color2)
  # ax_sec.legend()

  counter += 1

# df[info[counter][1]]

# %%
#Current vs voltage plots
# df.plot(y='Ia',x='Va',color ='tab:orange');
# df.plot(y='Ia',x='Vb',color ='tab:pink');
# df.plot(y='Ia',x='Vc',color ='tab:red');
# df.plot(y='Ib',x='Va',color ='tab:purple');
# df.plot(y='Ib',x='Vb', color ='tab:blue');
# df.plot(y='Ib',x='Vc', color ='tab:brown');
# df.plot(y='Ic',x='Va',color ='tab:green');
# df.plot(y='Ic',x='Vb');
# df.plot(y='Ic',x='Vc',color ='tab:grey');

# %%
import matplotlib.pyplot as plt
data_tuple = (('Ia', 'Line A Cureent', 'green'), ('Ib', 'Line B Cureent', 'yellow'),
              ('Ic', 'Line C Cureent', 'orange'), ('Va', 'Line A Voltage', 'red'),
               ('Vb', 'Line B Voltage', 'purple'), ('Vc', 'Line C Voltage', 'blue'))

nrows, ncols = 2, 3
counter = 0 # keeps track of the index of the data_tuple

fig, axes = plt.subplots(nrows = nrows, ncols=ncols, figsize = (18,10))
for row in range(nrows):
  for col in range(ncols):
    ax = axes[row][col]
    ax.hist(df[data_tuple[counter][0]], bins=10, edgecolor='black',
            color=data_tuple[counter][2], label=data_tuple[counter][0] )
    ax.set_xlabel('Values')
    ax.set_ylabel('frequency')
    ax.set_title(f'Distribution of {data_tuple[counter][1]}')
    ax.legend()
    counter += 1

# %%
import matplotlib.pyplot as plt

#creating histograms to get an idea of the distribution ofthe predictors and labels

plt.hist(df['Ia'], bins=10, edgecolor='black',color='green')
# Out:
# (array([ 790.,  479.,  334.,  279., 2033., 1889.,  328.,  361.,  444.,
#          924.]),
#  array([-883.5423165 , -706.61422778, -529.68613906, -352.75805034,
#         -175.82996162,    1.0981271 ,  178.02621582,  354.95430454,
#          531.88239326,  708.81048198,  885.7385707 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['Ib'], bins=10, edgecolor='black', color='yellow')
# Out:
# (array([ 878.,  517.,  389.,  348., 1567., 2654.,  317.,  271.,  320.,
#          600.]),
#  array([-900.5269515 , -721.48736797, -542.44778444, -363.40820091,
#         -184.36861738,   -5.32903385,  173.71054968,  352.75013321,
#          531.78971674,  710.82930027,  889.8688838 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['Ic'], bins=10, edgecolor='black',color='orange')
# Out:
# (array([ 413.,  259.,  195.,  177., 3300., 1939.,  266.,  301.,  410.,
#          601.]),
#  array([-883.3577621 , -704.89455982, -526.43135754, -347.96815526,
#         -169.50495298,    8.9582493 ,  187.42145158,  365.88465386,
#          544.34785614,  722.81105842,  901.2742607 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['Va'], bins=10, edgecolor='black',color='red')
# Out:
# (array([ 565.,  453.,  532.,  401., 1772., 2163.,  411.,  488.,  505.,
#          571.]),
#  array([-0.62074797, -0.49913895, -0.37752994, -0.25592092, -0.13431191,
#         -0.01270289,  0.10890612,  0.23051514,  0.35212415,  0.47373317,
#          0.59534218]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['Vb'], bins=10, edgecolor='black',color='purple')
# Out:
# (array([ 762.,  469.,  495.,  378., 2049., 1683.,  380.,  592.,  335.,
#          718.]),
#  array([-0.608016  , -0.48442693, -0.36083785, -0.23724877, -0.1136597 ,
#          0.00992938,  0.13351845,  0.25710753,  0.38069661,  0.50428568,
#          0.62787476]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['Vc'], bins=10, edgecolor='black')
# Out:
# (array([ 620.,  339.,  841.,  561., 1268., 1681.,  560.,  950.,  339.,
#          702.]),
#  array([-0.61270917, -0.49142037, -0.37013158, -0.24884278, -0.12755398,
#         -0.00626518,  0.11502361,  0.23631241,  0.35760121,  0.47889001,
#          0.6001788 ]),
#  <BarContainer object of 10 artists>)

# %%
#6 bins for the 6 output classes
plt.hist(df['combined_faults_label'], bins=6, edgecolor='black',color='grey')
# Out:
# (array([1129., 1134., 1004., 1096., 1133., 2365.]),
#  array([0.        , 0.83333333, 1.66666667, 2.5       , 3.33333333,
#         4.16666667, 5.        ]),
#  <BarContainer object of 6 artists>)

# %%
#We observe similar distribution for Ia, Ib and Ic. The distribution for Va, Vb and Vc seem to mimic each other as well.
#There doesn't seem to be a major imbalance in the 5 output classes representing electrical faults
#Getting a count of the various output classes
x = df['combined_faults_label'].value_counts()
print("Count of fault:\n",x)
# Out:
# Count of fault:
#  0000    2365
# 1011    1134
# 1111    1133
# 1001    1129
# 0111    1096
# 0110    1004
# Name: combined_faults_label, dtype: int64

# %%
print('% of labels representing no fault(0000)=', 100*2365/7861)
print('% of labels representing LLG Fault-Between Phases A,B and ground(1011)=', 100*1134/7861)
print('% of labels representing LLLG fault-Three phase symmetrical fault(1111)=', 100*1133/7861)
print('% of labels representing LG fault-Between Phase A and ground(1001)=', 100*1129/7861)
print('% of labels representing LLL Fault-Between all three phases(0111)=', 100*1096/7861)
print('% of labels representing LL fault-Between Phase B and Phase C(0110)=', 100*1004/7861)
# Out:
# % of labels representing no fault(0000)= 30.08523088665564
# % of labels representing LLG Fault-Between Phases A,B and ground(1011)= 14.425645592163846
# % of labels representing LLLG fault-Three phase symmetrical fault(1111)= 14.412924564304795
# % of labels representing LG fault-Between Phase A and ground(1001)= 14.362040452868591
# % of labels representing LLL Fault-Between all three phases(0111)= 13.942246533519908
# % of labels representing LL fault-Between Phase B and Phase C(0110)= 12.771911970487215

# %%
pd.plotting.scatter_matrix(df[['Ia','Ib','Ic','Va','Vb','Vc']])
# Out:
# array([[<AxesSubplot:xlabel='Ia', ylabel='Ia'>,
#         <AxesSubplot:xlabel='Ib', ylabel='Ia'>,
#         <AxesSubplot:xlabel='Ic', ylabel='Ia'>,
#         <AxesSubplot:xlabel='Va', ylabel='Ia'>,
#         <AxesSubplot:xlabel='Vb', ylabel='Ia'>,
#         <AxesSubplot:xlabel='Vc', ylabel='Ia'>],
#        [<AxesSubplot:xlabel='Ia', ylabel='Ib'>,
#         <AxesSubplot:xlabel='Ib', ylabel='Ib'>,
#         <AxesSubplot:xlabel='Ic', ylabel='Ib'>,
#         <AxesSubplot:xlabel='Va', ylabel='Ib'>,
#         <AxesSubplot:xlabel='Vb', ylabel='Ib'>,
#         <AxesSubplot:xlabel='Vc', ylabel='Ib'>],
#        [<AxesSubplot:xlabel='Ia', ylabel='Ic'>,
#         <AxesSubplot:xlabel='Ib', ylabel='Ic'>,
#         <AxesSubplot:xlabel='Ic', ylabel='Ic'>,
#         <AxesSubplot:xlabel='Va', ylabel='Ic'>,
#         <AxesSubplot:xlabel='Vb', ylabel='Ic'>,
#         <AxesSubplot:xlabel='Vc', ylabel='Ic'>],
#        [<AxesSubplot:xlabel='Ia', ylabel='Va'>,
# ...

# %%
import seaborn as sns
# %matplotlib inline

plt.figure(figsize=(10,8))
sns.heatmap(df[['Ia','Ib', 'Ic', 'Va', 'Vb', 'Vc']].corr(),
            annot = True, fmt='.1g',
            vmin=-1, vmax=1, center= 0, cmap= 'Greens' ,
            linewidths=6, linecolor='black')
plt.title('Correlation matrix')
# Out:
# Text(0.5, 1.0, 'Correlation matrix')

# %% [markdown]
# # Feature Engineering

# %%
# features and Target Variables
X = df[['Ia','Ib', 'Ic', 'Va', 'Vb', 'Vc']] # Features
y = df['combined_faults_label'] # target

# %%
# Try a cosine transformation
from sklearn.preprocessing import FunctionTransformer

# transformer = FunctionTransformer(np.cos)
# X = transformer.fit_transform(X)

# %%
# Removing negative values from the features
# All values are between 0 and about 2700

for col in X.columns:
  X[col] = X[col] + abs(X[col])

# X
# Out:
# C:\Users\ishaj\AppData\Local\Temp/ipykernel_12500/4179309707.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[col] = X[col] + abs(X[col])

# %%
# !pip install -U imbalanced-learn

# %%
# Under Sample the data
from imblearn.under_sampling import RandomUnderSampler

# Keeping 1165 no fault samples
# rus = RandomUnderSampler(sampling_strategy={'0000': 1165}, random_state=42)
# X, y = rus.fit_resample(X, y)

y.value_counts()
# Out:
# 0000    2365
# 1011    1134
# 1111    1133
# 1001    1129
# 0111    1096
# 0110    1004
# Name: combined_faults_label, dtype: int64

# %%
# from sklearn.preprocessing import StandardScaler

# scalar = StandardScaler()
# X = scalar.fit_transform(X)

# %%
# Splitting data into train and test sets
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

print(f'X_train shape: {X_train.shape}')
print(f'X_test shape: {X_test.shape}')
print(f'y_train shape: {y_train.shape}')
print(f'y_test shape: {y_test.shape}')
# Out:
# X_train shape: (5895, 6)
# X_test shape: (1966, 6)
# y_train shape: (5895,)
# y_test shape: (1966,)

# %%
# # Standardizing the training dataset
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# # Initialize the scaler
scaler = MinMaxScaler()

# # Fit the scaler on the training data
scaler.fit(X_train)

# # Scale the training data
X_train_scaled = scaler.transform(X_train)

# # Scale the test data
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# #LOGISTIC REGRESSION

# %%
#Logistic Regression

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# Initialize the Logistic Regression classifier
# The 'lbfgs' solver is a good default choice; for very large datasets or multiclass classification, 'sag' or 'saga' might be more appropriate
logreg = LogisticRegression(multi_class='ovr', solver='lbfgs', max_iter=1000)

# Fit the model to the training data
logreg.fit(X_train_scaled, y_train)

# Predict the labels for the test set
y_pred = logreg.predict(X_test_scaled)

# Predicting on the training set
train_predictions = logreg.predict(X_train_scaled)

# Calculating the accuracy on the training set
train_accuracy = accuracy_score(y_train, train_predictions)

print(f"Training Set Accuracy: {train_accuracy}")

# Calculate the accuracy
accuracy = accuracy_score(y_test, y_pred)

# Print the accuracy
print(f"Test Set Accuracy: {accuracy:.2f}")

# Print a classification report to see metrics by class
print(classification_report(y_test, y_pred))
# Out:
# Training Set Accuracy: 0.6517387616624258
# Test Set Accuracy: 0.65
#               precision    recall  f1-score   support
#
#         0000       0.77      1.00      0.87       601
#         0110       0.80      0.62      0.70       247
#         0111       0.43      0.45      0.44       249
#         1001       0.54      0.36      0.43       302
#         1011       0.62      0.60      0.61       291
#         1111       0.49      0.44      0.46       276
#
#     accuracy                           0.65      1966
#    macro avg       0.61      0.58      0.59      1966
# weighted avg       0.63      0.65      0.63      1966

# %%
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression

# Define the model with the desired settings
logreg = LogisticRegression(multi_class='multinomial', solver='lbfgs', max_iter=1000)

# Create a pipeline that first standardizes the data then fits the model
# This ensures each fold is scaled based on its training data
pipeline = make_pipeline(StandardScaler(), logreg)

# Choose the number of folds for cross-validation, 10 is a common choice
num_folds = 10

# Perform cross-validation
scores = cross_val_score(pipeline, X, y, cv=num_folds, scoring='accuracy')

# Calculate the average accuracy and the standard deviation
average_accuracy = scores.mean()
standard_deviation = scores.std()

# Output the results
print(f'Cross-validated accuracy: {average_accuracy:.3f}')
print(f'Standard Deviation: {standard_deviation:.3f}')
# Out:
# Cross-validated accuracy: 0.621
# Standard Deviation: 0.058

# %% [markdown]
# #KNN

# %%
# KNN

from sklearn.neighbors import KNeighborsClassifier

# Initialize the KNN classifier
knn = KNeighborsClassifier() # You can choose the best value for n_neighbors

# Fit the model on the scaled training data
knn.fit(X_train_scaled, y_train)

# Predicting on the training set
train_predictions = knn.predict(X_train_scaled)

# Calculating the accuracy on the training set
train_accuracy = accuracy_score(y_train, train_predictions)

print(f"Training Set Accuracy: {train_accuracy}")


# Predict the labels for the test set
y_pred = knn.predict(X_test_scaled)

# Optionally, evaluate the model's performance
from sklearn.metrics import classification_report, accuracy_score

print(classification_report(y_test, y_pred))
print(f'Accuracy: {accuracy_score(y_test, y_pred)}')
# Out:
# Training Set Accuracy: 0.8525869380831212
#               precision    recall  f1-score   support
#
#         0000       0.99      0.99      0.99       601
#         0110       1.00      0.99      0.99       247
#         0111       0.28      0.31      0.30       249
#         1001       0.95      0.96      0.96       302
#         1011       0.94      0.96      0.95       291
#         1111       0.30      0.26      0.28       276
#
#     accuracy                           0.79      1966
#    macro avg       0.74      0.75      0.74      1966
# weighted avg       0.79      0.79      0.79      1966
#
# Accuracy: 0.7934893184130214

# %%
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

# Create a pipeline that first standardizes the data then fits the model
# This ensures each fold is scaled based on its training data
pipeline = make_pipeline(StandardScaler(), knn)

# Choose the number of folds for cross-validation, 10 is a common choice
num_folds = 10

# Perform cross-validation
scores = cross_val_score(pipeline, X, y, cv=num_folds, scoring='accuracy')

# Calculate the average accuracy and the standard deviation
average_accuracy = scores.mean()
standard_deviation = scores.std()

# Output the results
print(f'Cross-validated accuracy: {average_accuracy:.3f}')
print(f'Standard Deviation: {standard_deviation:.3f}')
# Out:
# Cross-validated accuracy: 0.825
# Standard Deviation: 0.078

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you have your test labels as y_test and predictions as y_pred
cm = confusion_matrix(y_test, y_pred)

# Plotting the confusion matrix
plt.figure(figsize=(10,7))
sns.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# **Tuning the parameters for k-Nearest Neighbours**

# %%
from sklearn.model_selection import StratifiedKFold, GridSearchCV, KFold
# StratifiedkFold retains the percentages of the each class in each fold
knn = KNeighborsClassifier()
folds = 10
kfold = StratifiedKFold(folds, shuffle=True, random_state=42)

# tuning the 'n_neighbors' parameter to find the best model

n_neighbors=[2,3,4,5,6,7,8,8,10,11,12]

#Using scaled X as k nearest neighbours is a distance based algorithm
knn_grid = GridSearchCV(knn ,{'n_neighbors': n_neighbors},
                        refit=True ,cv=kfold, scoring='accuracy')
knn_grid.fit(X_train_scaled, y_train)
knn_grid.best_params_
# Out:
# {'n_neighbors': 2}

# %%
# plotting the cross validation error
from sklearn.model_selection import cross_validate
scores = []

for n in n_neighbors:
    knn = KNeighborsClassifier(n_neighbors=n)
    M_CV = cross_validate(knn, X_train_scaled, y_train, cv=kfold, scoring='accuracy')
    scores.append(1 - np.mean(M_CV['test_score']))

ax = plt.subplots(figsize=(10,6))[1]
ax.plot(n_neighbors, scores, color='purple')
ax.set_xlabel('Number of Neighbors')
ax.set_ylabel('Cross validation Error')
# Out:
# Text(0, 0.5, 'Cross validation Error')

# %%
knn_2n = KNeighborsClassifier(n_neighbors=2)
knn_8n = KNeighborsClassifier(n_neighbors=8)

# %%
#Performance with k=2
knn_2n.fit(X_train_scaled, y_train)

# Predict the labels for the test set
y_pred = knn_2n.predict(X_test_scaled)

# Model performance evaluation
print(classification_report(y_test, y_pred))
print(f'Test accuracy: {accuracy_score(y_test, y_pred)}')
# Out:
#               precision    recall  f1-score   support
#
#         0000       1.00      1.00      1.00       601
#         0110       1.00      1.00      1.00       247
#         0111       0.43      0.76      0.55       249
#         1001       0.96      1.00      0.98       302
#         1011       0.99      0.96      0.97       291
#         1111       0.31      0.10      0.15       276
#
#     accuracy                           0.84      1966
#    macro avg       0.78      0.80      0.78      1966
# weighted avg       0.82      0.84      0.82      1966
#
# Test accuracy: 0.8357070193285859

# %%
# Confusion Matrix
from sklearn.metrics import ConfusionMatrixDisplay

matrix = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(matrix, display_labels=knn_2n.classes_)
disp.plot()

# %%
#Performance with k=8
knn_8n.fit(X_train_scaled, y_train)

# Predict the labels for the test set
y_pred = knn_8n.predict(X_test_scaled)

# Model performance evaluation
print(classification_report(y_test, y_pred))
print(f'Test accuracy: {accuracy_score(y_test, y_pred)}')
# Out:
#               precision    recall  f1-score   support
#
#         0000       0.99      0.99      0.99       601
#         0110       0.99      0.99      0.99       247
#         0111       0.44      0.67      0.53       249
#         1001       0.95      0.96      0.95       302
#         1011       0.89      0.96      0.93       291
#         1111       0.34      0.14      0.20       276
#
#     accuracy                           0.82      1966
#    macro avg       0.77      0.79      0.77      1966
# weighted avg       0.81      0.82      0.81      1966
#
# Test accuracy: 0.8224821973550356

# %%
# Confusion Matrix

matrix = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(matrix, display_labels=knn_8n.classes_)
disp.plot()

# %% [markdown]
# #Decision Tree

# %%
#Decision trees

from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, accuracy_score

# Initialize the Decision Tree Classifier
dt_classifier = DecisionTreeClassifier(max_depth = 10, random_state=0)

# Train the classifier on the training data
dt_classifier.fit(X_train, y_train)

# Predicting on the training set
train_predictions = dt_classifier.predict(X_train)

# Calculating the accuracy on the training set
train_accuracy = accuracy_score(y_train, train_predictions)

print(f"Training Set Accuracy: {train_accuracy}")


# Predict the labels for the test set
y_pred = dt_classifier.predict(X_test)

# Evaluate the performance
print(classification_report(y_test, y_pred))
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')
# Out:
# Training Set Accuracy: 0.8637828668363019
#               precision    recall  f1-score   support
#
#         0000       0.99      0.99      0.99       601
#         0110       1.00      0.97      0.98       247
#         0111       0.45      0.42      0.44       249
#         1001       0.96      0.93      0.94       302
#         1011       0.90      0.96      0.93       291
#         1111       0.48      0.50      0.49       276
#
#     accuracy                           0.83      1966
#    macro avg       0.80      0.79      0.79      1966
# weighted avg       0.83      0.83      0.83      1966
#
# Accuracy: 0.8331637843336724

# %%
# Create a pipeline that first standardizes the data then fits the model
# This ensures each fold is scaled based on its training data
pipeline = make_pipeline(dt_classifier)

# Choose the number of folds for cross-validation, 10 is a common choice
num_folds = 10

# Perform cross-validation
scores = cross_val_score(pipeline, X, y, cv=num_folds, scoring='accuracy')

# Calculate the average accuracy and the standard deviation
average_accuracy = scores.mean()
standard_deviation = scores.std()

# Output the results
print(f'Cross-validated accuracy: {average_accuracy:.3f}')
print(f'Standard Deviation: {standard_deviation:.3f}')
# Out:
# Cross-validated accuracy: 0.811
# Standard Deviation: 0.054

# %% [markdown]
# ## Tuning the parameters of the Decision Tree

# %%
from sklearn.model_selection import StratifiedKFold, GridSearchCV, KFold
# StratifiedkFold retains the percentages of the each class in each fold

folds = 10
kfold = StratifiedKFold(folds, shuffle=True, random_state=42)

# tuning the 'max_depth' parameter to find the best tree classifier using cross
# validation

max_depths = range(1,21)
tree = DecisionTreeClassifier()

dt_grid = GridSearchCV(tree ,{'max_depth': max_depths},
                        refit=True ,cv=kfold, scoring='accuracy')
dt_grid.fit(X_train, y_train)
dt_grid.best_params_
# Out:
# {'max_depth': 18}

# %%
# plot the cross validation error
from sklearn.model_selection import cross_validate
scores = []

for depth in max_depths:
    tree = DecisionTreeClassifier(max_depth=depth)
    M_CV = cross_validate(tree, X_train, y_train, cv=kfold, scoring='accuracy')
    scores.append(1 - np.mean(M_CV['test_score']))

ax = plt.subplots(figsize=(10,6))[1]
ax.plot(max_depths, scores)
ax.set_xlabel('Tree Depth')
ax.set_ylabel('Cross validation Error')
# Out:
# Text(0, 0.5, 'Cross validation Error')

# %%
unpruned_dt_test_acc = accuracy_score(y_test, dt_grid.predict(X_test))
unpruned_dt_test_acc
# Out:
# 0.8570701932858596

# %%
# pruning the best tree
tree = DecisionTreeClassifier(max_depth = dt_grid.best_params_['max_depth'])
ccp_path = tree.cost_complexity_pruning_path(X_train , y_train)

pruned_dt_grid = GridSearchCV(tree ,{'ccp_alpha': ccp_path.ccp_alphas},
                        refit=True ,cv=kfold, scoring='accuracy')

pruned_dt_grid.fit(X_train, y_train)
pruned_dt_test_acc = accuracy_score(y_test, pruned_dt_grid.predict(X_test))
pruned_dt_test_acc
# Out:
# 0.8489318413021363

# %%
# Confusion Matrix
from sklearn.metrics import ConfusionMatrixDisplay

matrix = confusion_matrix(y_test, pruned_dt_grid.predict(X_test))
disp = ConfusionMatrixDisplay(matrix, display_labels=pruned_dt_grid.classes_)
disp.plot()

# %% [markdown]
# #RANDOM FOREST

# %%
#Random forest

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score

# Initialize the Random Forest classifier
# You can adjust n_estimators (the number of trees) and other parameters to tune the model
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=0)


# Train the classifier on the training data
rf_classifier.fit(X_train, y_train)

# Predicting on the training set
train_predictions = rf_classifier.predict(X_train)

# Calculating the accuracy on the training set
train_accuracy = accuracy_score(y_train, train_predictions)

print(f"Training Set Accuracy: {train_accuracy}")

# Predict the labels for the test set
y_pred_rf = rf_classifier.predict(X_test)

# Evaluate the performance
print(classification_report(y_test, y_pred_rf))
accuracy_rf = accuracy_score(y_test, y_pred_rf)
print(f'Test Accuracy: {accuracy_rf}')
# Out:
# Training Set Accuracy: 1.0
#               precision    recall  f1-score   support
#
#         0000       1.00      1.00      1.00       601
#         0110       1.00      1.00      1.00       247
#         0111       0.51      0.55      0.53       249
#         1001       0.99      1.00      0.99       302
#         1011       1.00      0.98      0.99       291
#         1111       0.56      0.52      0.54       276
#
#     accuracy                           0.87      1966
#    macro avg       0.84      0.84      0.84      1966
# weighted avg       0.87      0.87      0.87      1966
#
# Test Accuracy: 0.8723296032553408

# %%
# from sklearn.model_selection import cross_val_score
# from sklearn.preprocessing import StandardScaler
# from sklearn.pipeline import make_pipeline

# # Create a pipeline that first standardizes the data then fits the model
# # This ensures each fold is scaled based on its training data
# pipeline = make_pipeline(rf_classifier)

# # Choose the number of folds for cross-validation, 10 is a common choice
# num_folds = 10

# # Perform cross-validation
# scores = cross_val_score(pipeline, X, y, cv=num_folds, scoring='accuracy')

# # Calculate the average accuracy and the standard deviation
# average_accuracy = scores.mean()
# standard_deviation = scores.std()

# # Output the results
# print(f'Cross-validated accuracy: {average_accuracy:.3f}')
# print(f'Standard Deviation: {standard_deviation:.3f}')

# %% [markdown]
# ## Tuning the parameters of random forest classifier

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'n_estimators': [100,200,300,400,500]
    # 'max_features': ['sqrt', 'log2', None],
    # 'max_depth': [5,10,15,20],
    # 'max_leaf_nodes': [3, 6, 9],
}

# %%
grid_search = GridSearchCV(RandomForestClassifier(random_state=0),
                           param_grid=param_grid,n_jobs=-1,cv=5)
grid_search.fit(X_train, y_train)
print(grid_search.best_estimator_)
# Out:
# RandomForestClassifier(n_estimators=400, random_state=0)

# %%
grid_search.best_params_
# Out:
# {'n_estimators': 400}

# %%
model_grid = RandomForestClassifier(
									# max_features='log2',
									# max_leaf_nodes=9,
									n_estimators=400)
model_grid.fit(X_train, y_train)
y_pred_grid = model_grid.predict(X_test)
print(classification_report(y_pred_grid, y_test))
# Out:
#               precision    recall  f1-score   support
#
#         0000       1.00      1.00      1.00       603
#         0110       1.00      1.00      1.00       247
#         0111       0.56      0.51      0.54       272
#         1001       1.00      0.99      0.99       305
#         1011       0.98      1.00      0.99       287
#         1111       0.52      0.57      0.55       252
#
#     accuracy                           0.87      1966
#    macro avg       0.84      0.84      0.84      1966
# weighted avg       0.87      0.87      0.87      1966

# %%
acc = accuracy_score(y_true=y_test,y_pred=y_pred_grid)
acc
# Out:
# 0.873855544252289

# %%
rf_classifier.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 0,
#  'verbose': 0,
#  'warm_start': False}

# %%
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import confusion_matrix


matrix = confusion_matrix(y_test, y_pred_grid)
disp = ConfusionMatrixDisplay(matrix, display_labels= model_grid.classes_)
disp.plot()

# %%
n_estimators= [100,200,300,400,500]

# %%
from sklearn.model_selection import cross_validate
scores_rf = []

for estimator in n_estimators:
    forest= RandomForestClassifier(n_estimators=estimator,random_state=0)
    RF_CV = cross_validate(forest, X_train, y_train, cv=5, scoring='accuracy')
    scores_rf.append(1 - np.mean(RF_CV['test_score']))

ax = plt.subplots(figsize=(10,6))[1]
ax.plot(n_estimators, scores_rf)
ax.set_xlabel('Estimator')
ax.set_ylabel('Cross validation Error')
# Out:
# Text(0, 0.5, 'Cross validation Error')

# %%
scores_rf
# Out:
# [0.1518235793044953,
#  0.15131467345207805,
#  0.15097540288379996,
#  0.15097540288379974,
#  0.151484308736217]

# %% [markdown]
# #SUPPORT VECTOR MACHINE

# %%
#Cross-validation

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report

# Initialize the SVC classifier with default hyperparameters for the baseline model
baseline_svc = SVC(random_state=0)

# Fit the classifier to the scaled training data
baseline_svc.fit(X_train_scaled, y_train)

# Predict and evaluate on the training set
train_predictions_baseline = baseline_svc.predict(X_train_scaled)
train_accuracy_baseline = accuracy_score(y_train, train_predictions_baseline)
print(f"Baseline Training Set Accuracy: {train_accuracy_baseline}")

# Predict and evaluate on the test set
y_pred_svc_baseline = baseline_svc.predict(X_test_scaled)
print(classification_report(y_test, y_pred_svc_baseline))
accuracy_svc_baseline = accuracy_score(y_test, y_pred_svc_baseline)
print(f'Baseline Test Accuracy: {accuracy_svc_baseline}')
# Out:
# Baseline Training Set Accuracy: 0.7760814249363868
#               precision    recall  f1-score   support
#
#         0000       0.86      1.00      0.93       601
#         0110       0.99      0.85      0.91       247
#         0111       0.44      0.82      0.57       249
#         1001       0.92      0.66      0.77       302
#         1011       0.82      0.89      0.85       291
#         1111       0.40      0.08      0.14       276
#
#     accuracy                           0.76      1966
#    macro avg       0.74      0.72      0.70      1966
# weighted avg       0.76      0.76      0.73      1966
#
# Baseline Test Accuracy: 0.7614445574771109

# %%
 # Define the parameter range for GridSearch
param_grid = {
    'C': [0.1, 1, 10, 100],  # Example values
    'gamma': [1, 0.1, 0.01, 0.001],  # Example values
    'kernel': ['rbf']  # Focusing on 'rbf' kernel for simplicity
}

# Initialize the GridSearchCV object with the SVC classifier and the parameter grid
grid = GridSearchCV(SVC(random_state=0), param_grid, refit=True, verbose=3, cv=5)

# Fit the grid search to the data
grid.fit(X_train_scaled, y_train)

# Print the best parameters found by GridSearchCV
print("Best parameters found by GridSearchCV:")
print(grid.best_params_)

# Predict and evaluate on the training set
train_predictions = grid.predict(X_train_scaled)
train_accuracy = accuracy_score(y_train, train_predictions)
print(f"Training Set Accuracy: {train_accuracy}")

# Predict and evaluate on the test set
y_pred_svc = grid.predict(X_test_scaled)
print(classification_report(y_test, y_pred_svc))
accuracy_svc = accuracy_score(y_test, y_pred_svc)
print(f'Test Accuracy: {accuracy_svc}')
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV 1/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.659 total time=   1.3s
# [CV 2/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.667 total time=   1.1s
# [CV 3/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.676 total time=   1.1s
# [CV 4/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.658 total time=   1.1s
# [CV 5/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.657 total time=   1.2s
# [CV 1/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.478 total time=   1.6s
# [CV 2/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.512 total time=   1.6s
# [CV 3/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.511 total time=   1.5s
# [CV 4/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.484 total time=   1.5s
# [CV 5/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.527 total time=   1.5s
# [CV 1/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.299 total time=   2.1s
# ...

# %%
# 'grid' is the GridSearchCV object after fitting it to the training data
best_svc_model = grid.best_estimator_

# use this model to make predictions or further evaluate its performance
#
test_predictions = best_svc_model.predict(X_test_scaled)
test_accuracy = accuracy_score(y_test, test_predictions)

# Print out the performance
print(f'Test Accuracy of the best SVC model: {test_accuracy}')
# Out:
# Test Accuracy of the best SVC model: 0.8326551373346898

# %%
# Visualization
cv_results = grid.cv_results_
scores = cv_results['mean_test_score']
C_values = param_grid['C']
gamma_values = param_grid['gamma']

# Reshaping the scores array
scores_matrix = np.array(scores).reshape(len(C_values), len(gamma_values))

# Plotting
plt.figure(figsize=(8, 6))
for idx, val in enumerate(C_values):
    plt.plot(gamma_values, scores_matrix[idx, :], label=f'C={val}')

plt.legend()
plt.xlabel('Gamma')
plt.ylabel('Mean Test Score')
plt.title('SVC Performance for Different C and Gamma Values')
plt.show()

# %%
# Confusion Matrix
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import confusion_matrix


matrix = confusion_matrix(y_test, best_svc_model.predict(X_test_scaled))
disp = ConfusionMatrixDisplay(matrix, display_labels=best_svc_model.classes_)
disp.plot()
